# %%
import pandas as pd

df1 = pd.read_csv(r'C:\Users\Madhavi\OneDrive\Desktop\ML-Workshop-master\PDS\winequality-red.csv')
df2 = pd.read_csv(r'C:\Users\Madhavi\OneDrive\Desktop\ML-Workshop-master\PDS\winequalityN.csv')

merge_df = pd.merge(df1, df2, how='outer', on='quality')
merge_df.head(11)
# Out:
#     fixed acidity_x  volatile acidity_x  citric acid_x  residual sugar_x  \
# 0              11.6                0.58           0.66               2.2
# 1              11.6                0.58           0.66               2.2
# 2              11.6                0.58           0.66               2.2
# 3              11.6                0.58           0.66               2.2
# 4              11.6                0.58           0.66               2.2
# 5              11.6                0.58           0.66               2.2
# 6              11.6                0.58           0.66               2.2
# 7              11.6                0.58           0.66               2.2
# 8              11.6                0.58           0.66               2.2
# 9              11.6                0.58           0.66               2.2
# 10             11.6                0.58           0.66               2.2
#
#     chlorides_x  free sulfur dioxide_x  total sulfur dioxide_x  density_x  \
# ...

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import zscore


merge_df.info()
merge_df.describe()
merge_df.isnull().sum()
merge_df.dropna()
merge_df.fillna(100)
print(merge_df['quality'].value_counts())
print('number of duplicates:\n')
merge_df.duplicated().sum()
# Out:
# quality
# 6    1809368
# 5    1455978
# 7     214721
# 4      11448
# 8       3474
# 3        300
# 9          5
# Name: count, dtype: int64
# number of duplicates:
# np.int64(1080839)

# %%
sns.scatterplot(x='fixed acidity_x', y='fixed acidity_y', data=merge_df)
plt.xlabel('Fixed Acidity (X)')
plt.ylabel('Fixed Acidity (Y)')
plt.title('Scatter Plot of Fixed Acidity X vs Y')
plt.show()

# %%
import matplotlib.pyplot as plt

# Sample 50 rows for better visualization
sampled_df = merge_df.sample(50)

# Plotting
plt.figure(figsize=(12, 6))
plt.bar(sampled_df.index, sampled_df['fixed acidity_x'], alpha=0.7, label='alcohol')
plt.bar(sampled_df.index, sampled_df['fixed acidity_y'], alpha=0.7, label='alcohol')
plt.xlabel('Sample Index')
plt.ylabel('Fixed Acidity')
plt.title('Bar Plot of Fixed Acidity X and Y')
plt.legend()
plt.show()

# %%
# Count the occurrences of each quality value
quality_counts = df1['quality'].value_counts()
# Plotting
plt.figure(figsize=(8, 8))
plt.pie(quality_counts, labels=quality_counts.index, autopct='%1.1f%%', startangle=140)
plt.title('Distribution of Wine Quality')
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(data=merge_df[['fixed acidity_x', 'fixed acidity_y']])
plt.xlabel('Fixed Acidity')
plt.ylabel('Values')
plt.title('Box Plot of Fixed Acidity X and Y')
plt.show()

# %%
import numpy as np

import matplotlib.pyplot as plt

# Generate data for the wave
x = np.linspace(0, 10, 1000)
y = np.sin(x)

# Plotting the wave
plt.figure(figsize=(10, 6))
plt.plot(x, y, label='Sine Wave')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Sine Wave Graph')
plt.legend()
plt.grid(True)
plt.show()

# %%
from scipy.stats import skew

# Calculate skewness
skewness_x = skew(x)
skewness_y = skew(y)

print(f'Skewness of x: {skewness_x}')
print(f'Skewness of y: {skewness_y}')
# Out:
# Skewness of x: 1.0554245451072534e-15
# Skewness of y: -0.4047317057883002

# %%
# Calculate Q1 (25th percentile) and Q3 (75th percentile)
Q1_x = np.percentile(x, 25)
Q3_x = np.percentile(x, 75)
Q1_y = np.percentile(y, 25)
Q3_y = np.percentile(y, 75)

# Calculate IQR
IQR_x = Q3_x - Q1_x
IQR_y = Q3_y - Q1_y

# Define the lower and upper bounds for outliers
lower_bound_x = Q1_x - 1.5 * IQR_x
upper_bound_x = Q3_x + 1.5 * IQR_x
lower_bound_y = Q1_y - 1.5 * IQR_y
upper_bound_y = Q3_y + 1.5 * IQR_y

# Identify outliers
outliers_x = x[(x < lower_bound_x) | (x > upper_bound_x)]
outliers_y = y[(y < lower_bound_y) | (y > upper_bound_y)]

print(f'Outliers in x: {outliers_x}')
print(f'Outliers in y: {outliers_y}')
# Out:
# Outliers in x: []
# Outliers in y: []

# %%
# Filter out the outliers in x and y
filtered_x = x[(x >= lower_bound_x) & (x <= upper_bound_x)]
filtered_y = y[(y >= lower_bound_y) & (y <= upper_bound_y)]

print(f'Filtered x: {filtered_x}')
print(f'Filtered y: {filtered_y}')
# Out:
# Filtered x: [ 0.          0.01001001  0.02002002  0.03003003  0.04004004  0.05005005
#   0.06006006  0.07007007  0.08008008  0.09009009  0.1001001   0.11011011
#   0.12012012  0.13013013  0.14014014  0.15015015  0.16016016  0.17017017
#   0.18018018  0.19019019  0.2002002   0.21021021  0.22022022  0.23023023
#   0.24024024  0.25025025  0.26026026  0.27027027  0.28028028  0.29029029
#   0.3003003   0.31031031  0.32032032  0.33033033  0.34034034  0.35035035
#   0.36036036  0.37037037  0.38038038  0.39039039  0.4004004   0.41041041
#   0.42042042  0.43043043  0.44044044  0.45045045  0.46046046  0.47047047
#   0.48048048  0.49049049  0.5005005   0.51051051  0.52052052  0.53053053
#   0.54054054  0.55055055  0.56056056  0.57057057  0.58058058  0.59059059
#   0.6006006   0.61061061  0.62062062  0.63063063  0.64064064  0.65065065
#   0.66066066  0.67067067  0.68068068  0.69069069  0.7007007   0.71071071
#   0.72072072  0.73073073  0.74074074  0.75075075  0.76076076  0.77077077
# ...

# %%
from scipy.stats import zscore

# Calculate z-scores for x and y
z_scores_x = zscore(x)
z_scores_y = zscore(y)

print(f'Z-scores for x: {z_scores_x}')
print(f'Z-scores for y: {z_scores_y}')
# Out:
# Z-scores for x: [-1.73031962 -1.72685552 -1.72339142 -1.71992731 -1.71646321 -1.71299911
#  -1.709535   -1.7060709  -1.7026068  -1.69914269 -1.69567859 -1.69221449
#  -1.68875038 -1.68528628 -1.68182218 -1.67835807 -1.67489397 -1.67142987
#  -1.66796576 -1.66450166 -1.66103755 -1.65757345 -1.65410935 -1.65064524
#  -1.64718114 -1.64371704 -1.64025293 -1.63678883 -1.63332473 -1.62986062
#  -1.62639652 -1.62293242 -1.61946831 -1.61600421 -1.61254011 -1.609076
#  -1.6056119  -1.6021478  -1.59868369 -1.59521959 -1.59175549 -1.58829138
#  -1.58482728 -1.58136318 -1.57789907 -1.57443497 -1.57097087 -1.56750676
#  -1.56404266 -1.56057856 -1.55711445 -1.55365035 -1.55018625 -1.54672214
#  -1.54325804 -1.53979394 -1.53632983 -1.53286573 -1.52940163 -1.52593752
#  -1.52247342 -1.51900932 -1.51554521 -1.51208111 -1.50861701 -1.5051529
#  -1.5016888  -1.4982247  -1.49476059 -1.49129649 -1.48783239 -1.48436828
#  -1.48090418 -1.47744008 -1.47397597 -1.47051187 -1.46704777 -1.46358366
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# Initialize the LabelEncoder
label_encoder = LabelEncoder()

# Fit and transform the z_scores_y array
encoded_z_scores_y = label_encoder.fit_transform(z_scores_y)

print(f'Encoded z_scores_y: {encoded_z_scores_y}')
# Out:
# Encoded z_scores_y: [372 376 380 384 388 392 396 400 404 408 412 416 420 424 428 432 436 440
#  444 448 452 456 460 464 468 472 476 480 484 488 492 496 500 504 508 512
#  516 520 524 528 532 536 540 544 548 552 556 560 564 568 572 576 580 584
#  588 592 596 600 604 608 612 616 620 624 628 632 636 640 644 648 652 656
#  660 664 668 672 676 680 684 688 692 696 700 704 708 712 716 720 724 728
#  732 736 740 744 748 752 756 760 764 768 772 776 780 784 788 792 796 800
#  804 808 812 816 820 824 828 832 836 840 844 848 852 856 860 864 868 872
#  876 880 884 888 892 896 900 904 908 912 916 920 924 928 932 936 940 944
#  948 952 956 960 964 968 972 976 980 984 988 992 996 999 995 991 987 983
#  979 975 971 967 963 959 955 951 947 943 939 935 931 927 923 919 915 911
#  907 903 899 895 891 887 883 879 875 871 867 863 859 855 851 847 843 839
#  835 831 827 823 819 815 811 807 803 799 795 791 787 783 779 775 771 767
#  763 759 755 751 747 743 739 735 731 727 723 719 715 711 707 703 699 695
# ...

# %%
from sklearn.model_selection import train_test_split

# Perform train-test split
z_scores_y_train, z_scores_y_test = train_test_split(z_scores_y, test_size=0.2, random_state=42)

print(f'Train set: {z_scores_y_train}')
print(f'Test set: {z_scores_y_test}')
# Out:
# Train set: [ 1.54388336e-01 -1.47773568e+00  6.61663590e-01 -1.25196563e+00
#   1.03217023e+00 -7.44110721e-01  1.22164450e+00  7.50543945e-02
#  -1.73370214e+00  1.11130750e+00  6.34274617e-01  1.20751276e+00
#  -2.80681115e-02  1.09335721e+00  1.29976942e-01 -5.32240655e-01
#   2.58456607e-01  6.32420353e-01  2.33435471e-01  8.06063579e-01
#  -1.42739522e-01  1.03786026e+00 -7.69385496e-01  4.32021465e-01
#   3.85651568e-01 -2.45492078e-01 -1.39183266e+00 -8.07403960e-01
#   2.75639468e-01 -1.46866032e+00 -7.22122739e-01 -1.02866522e+00
#  -1.76980429e+00 -1.03159742e+00  2.11656648e-01  1.83114408e-01
#   8.32165039e-01 -5.95831669e-01  1.13490215e+00 -5.61817300e-01
#  -2.30460669e-01  1.06282661e+00 -1.63920186e+00  1.21100137e+00
#  -1.57723208e-01  1.05700978e+00 -1.65432706e+00  7.70943179e-01
#   8.43819324e-01  1.37721329e-01  8.23543000e-01 -9.89301925e-01
#   1.22510364e+00  4.12519390e-01 -1.39649591e+00 -4.13024469e-01
# ...
